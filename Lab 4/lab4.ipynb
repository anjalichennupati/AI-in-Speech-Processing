# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
y,sr = librosa.load(r'E:\3rd Year\6th Sem\AI in Speech Processing\Labs\Lab 2\my_audio_a1.wav')

# %%
plt.figure(figsize=(10,4))
plt.plot(y)

# %%
fft_ = np.fft.fft(y)
print(fft_)
# Out:
# [-0.63339778+0.j          0.63993916+0.26601238j -0.48673272-0.49522326j
#  ...  0.32819349-0.65836879j -0.48673272+0.49522326j
#   0.63993916-0.26601238j]

# %%
plt.figure(figsize=(10,4))
plt.plot(abs(fft_))

# %%
ifft_ = np.fft.ifft(fft_)
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(ifft_)
plt.title('IFFT')
plt.subplot(1,2,2)
plt.plot(y)
plt.title(' original signal')
# Out:
# d:\Python\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\Python\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Text(0.5, 1.0, ' original signal')

# %%
from IPython.display import Audio

# %%
Audio(r'E:\3rd Year\6th Sem\AI in Speech Processing\Labs\Lab 2\my_audio_a1.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(y)
# Out:
# 30576

# %%
Audio(y[14000:22000],rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
word = y[14000:22000]

# %%
word_fft = np.fft.fft(word)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.abs(fft_))
plt.title('FFT')
plt.subplot(1,2,2)
plt.plot(np.abs(word_fft))
plt.title('word')
# Out:
# Text(0.5, 1.0, 'word')

# %%
y_22500,r = librosa.load(r'E:\3rd Year\6th Sem\AI in Speech Processing\Labs\Lab 2\my_audio_a1.wav',sr = 22500)
Audio(y_22500,rate = r)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_2 = np.fft.fft(y_22500[10000:10450])

# %%
plt.figure(figsize=(10,4))
plt.plot(abs(fft_2))

# %%
y = librosa.stft(y_22500,n_fft=450,hop_length=225)
print(y)
# Out:
# [[ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ... -1.2065167e-04+0.0000000e+00j
#    3.5338658e-03+0.0000000e+00j  1.8799173e-02+0.0000000e+00j]
#  [ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ... -9.0610312e-04-1.2283028e-03j
#    3.2113960e-03+3.2361005e-03j -1.2879889e-02-1.4159910e-02j]
#  [ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ... -2.9187489e-02+1.1699336e-02j
#    1.5290722e-02+5.5943266e-03j -6.6148257e-04+1.9778227e-02j]
#  ...
#  [ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ...  2.4032822e-08+2.0328990e-07j
#    1.6879757e-07-2.5802368e-07j  4.9023504e-07-3.6953440e-07j]
#  [ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ... -7.3455453e-08+2.2807335e-08j
#    1.5990148e-08+2.1791985e-08j  6.5115934e-08-1.7799562e-07j]
#  [ 0.0000000e+00+0.0000000e+00j  0.0000000e+00+0.0000000e+00j
#    0.0000000e+00+0.0000000e+00j ... -6.4643395e-08+0.0000000e+00j
#   -2.3876011e-08+0.0000000e+00j  2.1898909e-07+0.0000000e+00j]]

# %%
from scipy.signal import spectrogram

# %%
freq_spectogram, times_spectogram, spectrogram_matrix = spectrogram(y,22500)
plt.figure(figsize=(14, 5))
plt.imshow(np.log(spectrogram_matrix), aspect='auto', origin='lower', cmap='viridis')
plt.colorbar()
plt.title("Spectrogram using scipy.signal.spectrogram()")
plt.xlabel("Time")
plt.ylabel("Frequency Bin")
plt.show()
# Out:
# C:\Users\Anjali\AppData\Local\Temp\ipykernel_13956\2911433430.py:1: UserWarning: nperseg = 256 is greater than input length  = 139, using nperseg = 139
#   freq_spectogram, times_spectogram, spectrogram_matrix = spectrogram(y,22500)
# C:\Users\Anjali\AppData\Local\Temp\ipykernel_13956\2911433430.py:1: UserWarning: Input data is complex, switching to return_onesided=False
#   freq_spectogram, times_spectogram, spectrogram_matrix = spectrogram(y,22500)
